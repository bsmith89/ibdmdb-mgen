# %%
import pandas as pd
import numpy as np

# %%
meta = pd.read_csv('raw/metadata/hmp2_metadata_2018-08-20.csv', low_memory=False)

# %%
for i, c in enumerate(meta.columns):
    print(f'{i}: {c}')
# Out:
# 0: Project
# 1: External ID
# 2: Participant ID
# 3: site_sub_coll
# 4: data_type
# 5: week_num
# 6: date_of_receipt
# 7: interval_days
# 8: visit_num
# 9: Research Project
# 10: PDO Number
# 11: GSSR IDs
# 12: Product
# 13: LCSET
# 14: Aggregated Lanes
# 15: WR ID
# 16: # Lanes in Aggregation
# 17: reads_raw
# 18: reads_filtered
# 19: reads_qc_fail
# 20: reads_human
# 21: reads_ribosomal
# 22: reads_viral
# 23: Delta
# 24: IntervalName
# 25: IntervalSequence
# 26: ProjectSpecificID
# 27: site_name
# 28: Age at diagnosis
# 29: Has the subject had a cholecystectomy?
# 30: Has the subject had a prior abdominal surgery (other)?
# 31: Has the next visit been scheduled?
# 32: Has the subject been given new stool kits?
# 33: Has the subject completed the FFQ/YAQ?
# 34: Education Level
# 35: Occupation
# 36: Scanned FFQ/YAQ document:
# 37: FFQ/YAQ results:
# 38: Has the subject had an appendectomy?
# 39: Has the subject had a tonsillectomy?
# 40: biopsy_location
# 41: Were study bloods drawn?
# 42: Whole blood received at Broad:
# 43: Serum tube #1 received at CSMC:
# 44: Serum tubes #2-4 received at MGH:
# 45: Whole Blood (DNA)
# 46: Serum #1
# 47: Serum #2
# 48: Serum #3
# 49: Serum #4
# 50: Number of flora tubes collected:
# 51: Rectum Flora:
# 52: Ileum flora:
# 53: Other inflamed flora:
# 54: Non-inflamed flora:
# 55: Have samples been sent for histopathology?
# 56: Number of tubes collected for epithelial cell biopsies:
# 57: Rectum cell biopsy:
# 58: Ileum cell biopsy:
# 59: Other inflamed cell biopsy:
# 60: Other non-inflamed cell biopsy:
# 61: FLora received at MGH:
# 62: RNA/DNA received at Broad:
# 63: ECP received at Washington U:
# 64: Number of DNA/RNA tubes collected:
# 65: Rectum DNA/RNA:
# 66: Ileum DNA/RNA:
# 67: Other Inflamed DNA/RNA:
# 68: Non-inflamed DNA/RNA:
# 69: consent_age
# 70: diagnosis
# 71: Soft drinks, tea or coffee with sugar (corn syrup, maple syrup, cane sugar, etc)
# 72: Diet soft drinks, tea or coffee with sugar (Stevia, Equal, Splenda etc)
# 73: Fruit juice (orange, apple, cranberry, prune etc.)
# 74: Water
# 75: Alcohol (beer, brandy, spirits, hard liquor, wine, aperitif, etc.)
# 76: Yogurt or other foods containing active bacterial cultures (kefir, sauerkraut)
# 77: Dairy (milk, cream, ice cream, cheese, cream cheese)
# 78: Probiotic
# 79: Fruits (no juice) (Apples, raisins, bananas, oranges, strawberries, blueberries
# 80: Vegetables (salad, tomatoes, onions, greens, carrots, peppers, green beans, etc)
# 81: 1) In the past 2 weeks, have you received any of the following medications
# 82: Beans (tofu, soy, soy burgers, lentils, Mexican beans, lima beans etc)
# 83: Whole grains (wheat, oats, brown rice, rye, quinoa, wheat bread, wheat pasta)
# 84: Starch (white rice, bread, pizza, potatoes, yams, cereals, pancakes, etc.)
# 85: Eggs
# 86: Processed meat (other red or white meat such as lunch meat, ham, salami, bologna
# 87: Red meat (beef, hamburger, pork, lamb)
# 88: White meat (chicken, turkey, etc.)
# 89: Shellfish (shrimp, lobster, scallops, etc.)
# 90: Fish (fish nuggets, breaded fish, fish cakes, salmon, tuna, etc.)
# 91: Sweets (pies, jam, chocolate, cake, cookies, etc.)
# 92: Antibiotics
# 93: Chemotherapy
# 94: Immunosuppressants (e.g. oral corticosteroids)
# 95: 2) In the past 2 weeks, have you undergone a colonoscopy or other procedure
# 96: 3) In the past 2 weeks, have you used an oral contrast
# 97: 4) In the past 2 weeks, have you had diarrhea?
# 98: 5) In the past 2 weeks, have you been hospitalized?
# 99: 6) Have you ever had bowel surgery?
# 100: Tea or coffee no sugar and no sugar replacement
# 101: Did you grow up on a farm?
# 102: Did you attend daycare as a child?
# 103: Were you exposed to cigarette smoke as a child?
# 104: Were you born prematurely (more than 3 weeks early)?
# 105: Do you currently smoke marijuana?
# 106: If yes, how many times per month do you smoke marijuana on average?
# 107: In the past 2 months, have you used any acid reducing medication
# 108: If yes, how frequently do you take them?
# 109: In the past 2 months, have you used any medications modifying bile production
# 110: Do you use non-steroidal anti-inflammatory medications
# 111: Were you born in a hospital?
# 112: If yes, how frequently do you take them?.1
# 113: If you are female, do you use hormonal contraception?
# 114: If yes, what type of contraception?
# 115: Please list your current hormonal contraceptive:
# 116: If yes, for how many months have you been taking hormonal contraception?
# 117: Have you changed your hormonal contraceptive regimen in the past two months?
# 118: In the past 6 months, have you used antibiotics?
# 119: In the past 3 months, have you consumed any probiotics (other than yogurt)
# 120: In the past 3 months, how often have you consumed yogurt or other foods containi
# 121: Were you born via C-section?
# 122: What are your dietary preferences with respect to meat?
# 123: How often do you consume alcoholic beverages?
# 124: In the past 7 days, my sleep quality was...
# 125: In the past 7 days, my sleep was refreshing...
# 126: I had a problem with my sleep...
# 127: I had difficulty falling asleep...
# 128: My sleep was restless...
# 129: I tried hard to get to sleep...
# 130: I worried about not being able to fall asleep...
# 131: I was satisfied with my sleep...
# 132: Were you born in the United States?
# 133: In the past 7 days, I felt worthless...
# 134: I felt helpless...
# 135: I felt depressed...
# 136: I felt hopeless...
# 137: I felt like a failure...
# 138: I felt unhappy...
# 139: I felt that I had nothing to look forward to...
# 140: I felt that nothing could cheer me up...
# 141: In the past 7 days, I felt fearful...
# 142: I found it hard to focus on anything other than my anxiety...
# 143: If no, where were you born?
# 144: If no, in what year did you come to the United States?
# 145: Were you breastfed as an infant?
# 146: My worries overwhelmed me...
# 147: I felt uneasy...
# 148: I felt nervous...
# 149: I felt like I needed help for my anxiety...
# 150: I felt anxious...
# 151: I felt tense...
# 152: When was the last time you saw a dentist (generalist, prosthodontist, periodonti
# 153: When was the last time you had a dental cleaning? Choose the most recent option.
# 154: Manual toothbrush
# 155: Electric toothbrush
# 156: Alcohol-based mouthwash
# 157: Non alcoholic mouthwash
# 158: Floss
# 159: Water-based pick/jet
# 160: Tongue cleaner
# 161: Tooth-whiteners
# 162: Were you treated with antibiotics before the age of one?
# 163: Were you hospitalized before the age of five?
# 164: Did you have pets growing up?
# 165: Subject is unwilling or unable to provide biopsy, blood, and stool samples:
# 166: Subject has an immune mediated disease (i.e. rheumatoid arthritis, lupus, T1DM):
# 167: Subject is pregnant:
# 168: Subject has a known bleeding disorder:
# 169: Subject has an acute gastrointestinal infection:
# 170: Subject is actively being treated for a malignancy with chemotherapy:
# 171: Subject has been diagnosed with indeterminate colitis:
# 172: Subject has a stoma or pouch:
# 173: Subject has an acute gastrointestinal illness:
# 174: Subject has an acute gastrointestinal infection or IBD:
# 175: Behavior (B)
# 176: For UC and CD, has the disease classification changed since baseline?
# 177: Extent (E)
# 178: For months 3, 6, and 9 ONLY: Has the subject been given 6 new stool collection k
# 179: Location (L) prior to first surgery
# 180: Has the subject experienced a flare since the last study visit?
# 181: If yes, how many times?
# 182: Weight
# 183: Has the subject had a colonoscopy since the last visit?
# 184: Has the subject been hospitalized for any reason since the last study visit?
# 185: Has the subject had any accute diarrheal illnesses since the last study visit?
# 186: Has the subject used any antibiotics since the last visit?
# 187: fecalcal_ng_ml
# 188: Parents
# 189: Mother
# 190: Father
# 191: Siblings
# 192: Male sibling 1
# 193: Male sibling 2
# 194: Male sibling 3
# 195: Female sibling 1
# 196: Female sibling 2
# 197: Female sibling 3
# 198: Children
# 199: Male child 1
# 200: Male child 2
# 201: Male child 3
# 202: Female child 1
# 203: Female child 2
# 204: Female child 3
# 205: Grandparents
# 206: Male grandparent 1
# 207: Male grandparent 2
# 208: Female grandparent 1
# 209: Female grandparent 2
# 210: Distant Relative
# 211: Male distant relative 1
# 212: Male distant relative 2
# 213: Male distant relative 3
# 214: Female distant relative 1
# 215: Female distant relative 2
# 216: Female distant relative 3
# 217: Uveitis
# 218: Erythema nodosum
# 219: Aphthous ulcers
# 220: Pyoderma gangrenosum
# 221: Anal fissure
# 222: New fistula
# 223: Abscess
# 224: Was HBI completed?
# 225: General wellbeing
# 226: Abdominal pain
# 227: Number of liquid or very soft stools in the past 24 hours:
# 228: Abdominal mass
# 229: Arthralgia
# 230: hbi
# 231: Hispanic or Latino Origin
# 232: BMI
# 233: Height
# 234: Weight.1
# 235: Cancer - breast
# 236: Cancer - cholangiocarcinoma
# 237: Cancer - colon or rectum
# 238: Cancer - Hodgkin's lymphoma
# 239: Cancer - liver
# 240: Cancer - lung
# 241: Cancer - lymphoma (not otherwise specified)
# 242: Cancer - Non-Hodkin's lymphoma
# 243: Cancer - ovarian
# 244: Cancer - prostate
# 245: Other immune mediated diseases
# 246: Celiac sprue
# 247: Chronic bronchitis
# 248: Dermatitis herpetiformis
# 249: Familial Mediterranean fever
# 250: Grave's disease
# 251: Guillian-Barre Syndrome
# 252: Hashimoto's (autoimmune) thyroiditis
# 253: Idiopathic pulmonary fibrosis
# 254: Idiopathic thrombocytopenia purpura
# 255: Irritable bowel syndrome
# 256: Alopecia areata
# 257: Multiple sclerosis
# 258: Myasthenia gravis
# 259: Myocarditis
# 260: Neuropathy
# 261: Pericarditis
# 262: Pemphigus vulgaris
# 263: Pernicious anemia
# 264: Polymyositis or dermatomyositis
# 265: Primary biliary cirrhosis
# 266: Primary sclerosing cholangitis
# 267: Ankylosing spondylitis
# 268: Psoriasis
# 269: Rheumatoid arthritis
# 270: Sarcoidosis
# 271: Scleroderma (systemic sclerosis)
# 272: Sjogren's syndrome
# 273: Systemic lupus erythematosis
# 274: Temporal arteritis
# 275: Thyroid disease (uncertain diagnosis, not cancer)
# 276: Type I Diabetes (Juvenile Diabetes)
# 277: Vitiligo
# 278: Arthritis (uncertain diagnosis)
# 279: Wegener's granulomatosis
# 280: Asthma
# 281: Autoimmune hemolytic anemia
# 282: Autoimmune hepatitis
# 283: Bechet's syndrome
# 284: Did the patient sign informed consent?
# 285: Did the subject withdraw from the study?
# 286: Was subject terminated by investigator?
# 287: Reason for withdrawal or termination:
# 288: Subject is 18 years of age or older:
# 289: Subject is 17 years of age or younger:
# 290: Subject has a confirmed diagnosis of IBD:
# 291: Subject was diagnosed within the last 6 months:
# 292: Subject is NOT on an anti-TNF inhibitor:
# 293: Subject has had IBD for 5 years or more:
# 294: is_inflamed
# 295: Have the following labs been drawn within +/- 2 weeks?
# 296: CRP (mg/L)
# 297: ESR (mm/hr)
# 298: Location
# 299: What is the endoscopic grading of severity?
# 300: Location.1
# 301: What is the endoscopic grading of severity?.1
# 302: Modified Baron's Score
# 303: Partial Endoscopy
# 304: Was the Modified Baron's Score completed?
# 305: Location.2
# 306: What is the endoscopic grading of severity?.2
# 307: Location.3
# 308: What is the endoscopic grading of severity?.3
# 309: Location.4
# 310: What is the endoscopic grading of severity?.4
# 311: Has classification been verified by a physician?
# 312: Age at diagnosis (A)
# 313: baseline_montreal_location
# 314: Behavior (B).1
# 315: Extent (E).1
# 316: Lomotil
# 317: Dipentum (olsalazine)
# 318: Reason for stopping Dipentum:
# 319: Rowasa enemas (mesalamine enemas)
# 320: Reason for stopping rowasa enemas:
# 321: Canasa suppositories (mesalamine suppositories)
# 322: Reason for stopping canasa suppositories:
# 323: Flagyl (Metronidazole)
# 324: Reason for stopping Flagyl:
# 325: Cipro (Ciprofloxin)
# 326: Reason for stopping Cipro:
# 327: Xifaxin (rifaxamin)
# 328: Reason for stopping Xifaxin:
# 329: Levaquin
# 330: Reason for stopping Levaquin:
# 331: Other Antibiotic:
# 332: Reason for stopping other antibiotic:
# 333: Prednisone
# 334: Reason for stopping Prednisone:
# 335: Highest dose of Prednisone taken (mg):
# 336: Entocort (Budesonide)
# 337: Reason for stopping Entocort:
# 338: Highest dose of Entocort taken (mg):
# 339: Reason for stopping lomotil:
# 340: Imodium
# 341: Solumedrol (Medrol)
# 342: Reason for stopping Solumedrol:
# 343: IV steroids
# 344: Reason for stopping IV steroids:
# 345: Cortenemas, Cortifoam, Proctofoam
# 346: Reason for stopping enemas or foam:
# 347: Azathioprine (Imuran, Azasan)
# 348: Reason for stopping Azathioprine:
# 349: Methotrexate
# 350: Reason for stopping Methotrexate:
# 351: Mercaptopurine (Purinethol, 6MP)
# 352: Reason for stopping Mercaptopurine:
# 353: VSL #3
# 354: Reason for stopping VSL #3:
# 355: FOS
# 356: Reason for stopping FOS:
# 357: Remicade (Infliximab)
# 358: Reason for stopping Remicade:
# 359: Duration of Remicade use (months):
# 360: Humira (Adalimumab)
# 361: Reason for stopping Humira:
# 362: Duration of Humira use (months):
# 363: Reason for stopping Imodium:
# 364: DTO
# 365: Cimzia (Certlizumab)
# 366: Reason for stopping Cimzia:
# 367: Duration of Cimzia use (months):
# 368: Tysabri (Natalizumab)
# 369: Reason for stopping Tysabri:
# 370: Duration of Tysabri use (months):
# 371: Reason for stopping:
# 372: Asacol (mesalamine)
# 373: Reason for stopping Asacol:
# 374: Pentasa (mesalamine)
# 375: Reason for stopping Pentasa:
# 376: Lialda (mesalamine)
# 377: Reason for stopping Lialda:
# 378: Apriso (mesalamine)
# 379: Reason for stopping Apriso:
# 380: Colozal (balasalizide)
# 381: Reason for stopping Colozal:
# 382: Sulfasalizine (Azulfidine)
# 383: Reason for stopping Sulfasalazine:
# 384: If other, explain:
# 385: Type of surgery:
# 386: Type of surgery:.1
# 387: Has subject had an upper or lower endoscopy?
# 388: Has IBD been confirmed by histopathology?
# 389: Has subject undergone any GI-related radiology procedures?
# 390: Procedure
# 391: Procedure.1
# 392: Has subject undergone any GI-related surgeries?
# 393: Type of surgery:.2
# 394: Type of surgery:.3
# 395: Type of surgery:.4
# 396: Disease_course
# 397: 2a. Red or sore eyes
# 398: 2b. An abscess (collection of puss) in your abdomen (belly)
# 399: 2c. An abscess on the buttock or around the anus
# 400: 2d. A narrowing of the bowel (a "stricture")
# 401: 2e. A fistula (an abdominal connection
# 402: 2f. A draining fistula (if you have a fistula to the skin)
# 403: 2g. Skin problems
# 404: 3a. Fever greater than 100 degrees Fahrenheit
# 405: 3b. Fatigue or lack of energy
# 406: 3c. Difficulty sleeping
# 407: 3d. Nausea
# 408: 3e. Vomiting
# 409: 3f. Mouth sores
# 410: 3g. Back pain
# 411: 3h. Night sweats
# 412: 3i. Decreased appetite
# 413: 3j. Weight loss
# 414: IN THE PAST SIX MONTHS, my disease has been:
# 415: 5a. How would you rate your health today with regard to your
# 416: 5b. How would you rate your health today with regard to you
# 417: race
# 418: Has the subject undergone any relevant GI imaging procedures (abdomen, pelvis et
# 419: Has the subject been given the C1 kit and asked to collect and submit a sample
# 420: Arthralgias
# 421: Pyoderma gangrenosum.1
# 422: Erythema nodosum.1
# 423: Uveitis.1
# 424: Was SCCAI completed?
# 425: Bowel frequency during the day
# 426: Bowel frequency during the night
# 427: Urgency of defecation
# 428: Blood in the stool
# 429: General well being over the past 24 hours
# 430: sccai
# 431: Screening Status
# 432: Ileum
# 433: Right Colon
# 434: Transverse Colon
# 435: Left Colon
# 436: Rectum
# 437: Total
# 438: Ileum.1
# 439: Right Colon.1
# 440: Transverse Colon.1
# 441: Left Colon.1
# 442: Rectum.1
# 443: Total.1
# 444: Ileum.2
# 445: Right Colon.2
# 446: Transverse Colon.2
# 447: Left Colon.2
# 448: Rectum.2
# 449: Total.2
# 450: Ileum.3
# 451: Right Colon.3
# 452: Transverse Colon.3
# 453: Left Colon.3
# 454: Rectum.3
# 455: Total.3
# 456: SES-CD Score
# 457: Partial Endoscopy.1
# 458: sex
# 459: 8. Felt relaxed and free of tension
# 460: 9. Troubled by a feeling of having to go to the bathroom
# 461: 10. Felt angry as a result of bowel problem
# 462: 1. Feeling of fatigue
# 463: 2. Delay or cancel a social engagement
# 464: 3. Difficulty doing leisure or sports activities
# 465: 4. How often during the last 2 weeks have you been troubled by pain in the abdom
# 466: 5. How often during the last two weeks have you felt depressed or discouraged? P
# 467: 6. Problem with passing large amounts of gas
# 468: 7. Problem with weight
# 469: SIBDQ Score
# 470: Specify race
# 471: Was stool sample collected?
# 472: Tube A: DNA/RNA
# 473: Tube A: Metabolomics
# 474: Tube A: Storage
# 475: Tube A:Viromics
# 476: Tube B:Fecal Calprotectin
# 477: fecalcal
# 478: Tube B:Proteomics
# 479: Viromics received at Baylor:
# 480: FecalCal received at MGH:
# 481: Proteomics received at LBNL:
# 482: Stool Sample ID:  Tube A  (EtOH)
# 483: Sample ID: Tube B (No preservative)
# 484: Tube A and B received at Broad:
# 485: stool_id
# 486: smoking status
# 487: Number years smoked
# 488: Age when started smoking
# 489: How many cigarettes/cigars/etc. do you smoke per day?

# %%
# Extract table: 'subject'.

column_rename = {
    'Participant ID': 'subject_id',
    'Age at diagnosis': 'ibd_diagnosis_at_age',
    'consent_age': 'age',
    'site_name': 'site',
    'Has the subject had a prior abdominal surgery (other)?': 'history_other_abdominal_surgery',
    'Education Level': 'education',
    'Occupation': 'occupation',
    'Has the subject had a tonsillectomy?': 'history_tonsillectomy',
    'diagnosis': 'ibd_diagnosis',
    'Did you grow up on a farm?': 'history_childhood_farm',
    'Did you attend daycare as a child?': 'history_childhood_daycare',
    'Were you exposed to cigarette smoke as a child?': 'history_childhood_environmental_tobacco_smoke',
    'Were you born prematurely (more than 3 weeks early)?': 'history_birth_premature',
    'Were you born in a hospital?': 'history_birth_hospital',
    'Were you born via C-section?': 'history_birth_csection',
    'Were you breastfed as an infant?': 'history_childhood_breastfed',
    'Were you treated with antibiotics before the age of one?': 'history_childhood_antibiotics_pre_age_one',
    'Were you hospitalized before the age of five?': 'history_childhood_antibiotics_pre_age_five',
    'Did you have pets growing up?': 'history_childhood_pets',
    'race': 'race',
    'sex': 'sex',
    'smoking status': 'status_smoker',
    'Number years smoked': 'status_smoker_years',
    'Age when started smoking': 'history_smoker_age_at_start',
    'How many cigarettes/cigars/etc. do you smoke per day?': 'status_smoker_number_per_day',
    'Height': 'baseline_height',
    'Weight.1': 'baseline_weight'
}

column_replace = {
    'history_other_abdominal_surgery': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'education':  {'Unknown/Not Reported': np.nan},
    'occupation':  {'Unknown/Not Reported': np.nan},
    'history_tonsillectomy': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_childhood_farm': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_childhood_daycare': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_childhood_environmental_tobacco_smoke': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_birth_premature': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_birth_hospital': {'Yes': True, 'No': False, 'Not sure': np.nan},  # Notice the different capitalization of 'Not sure'.
    'history_birth_csection': {'Yes': True, 'No': False, 'Not sure': np.nan},  # Notice the different capitalization of 'Not sure'.
    'history_childhood_breastfed': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_childhood_antibiotics_pre_age_one': {'Yes': True, 'No': False, 'Not sure': np.nan},  # Notice the different capitalization of 'Not sure'.
    'history_childhood_antibiotics_pre_age_five': {'Yes': True, 'No': False, 'Not Sure': np.nan},
    'history_childhood_pets': {'Yes': True, 'No': False, 'Not Sure': np.nan},
}


_subject = (meta[column_rename.keys()]  # Select columns of interest.
                .rename(columns=column_rename)  # Rename columns.
           )

# Replace malformed values
for col in column_replace:
    _subject[col].replace(column_replace[col], inplace=True)

# Fill NaNs when other valid values.
_subject = (_subject
                .groupby('subject_id')  
                .apply(lambda d: d.fillna(method='bfill').fillna(method='ffill'))
           )

_subject['history_smoker'] = _subject.status_smoker.replace({'Current smoker': True, 'Former smoker': True, 'Never smoked': False}).astype(float)
_subject['status_smoker'] = _subject.status_smoker.replace({'Current smoker': True, 'Former smoker': False, 'Never smoked': False}).astype(float)

n_unique_entries = _subject.drop_duplicates().shape[0]
n_unique_subjects = _subject.subject_id.unique().shape[0]
assert n_unique_subjects == n_unique_entries, (n_unique_subjects, n_unique_entries)

print(f"Found {n_unique_subjects} unique subjects.")

subject = _subject.drop_duplicates().set_index('subject_id')
assert subject.index.is_unique
# Out:
# Found 131 unique subjects.

# %%
# Extract table: 'visit'.

column_rename = {
    'site_sub_coll': 'visit_id',
    'Participant ID': 'subject_id',
    'week_num': 'week_number',
    'date_of_receipt': 'visit_date',
    'visit_num': 'visit_number',  # Visit number 1 CAN be after other visits; this describes the procedures done.
    'Soft drinks, tea or coffee with sugar (corn syrup, maple syrup, cane sugar, etc)': 'diet_sugary_beverage',
    'Diet soft drinks, tea or coffee with sugar (Stevia, Equal, Splenda etc)': 'diet_artificial_sweetener_beverage',
    'Fruit juice (orange, apple, cranberry, prune etc.)': 'diet_fruit_juice',
    'Water': 'diet_water',
    'Alcohol (beer, brandy, spirits, hard liquor, wine, aperitif, etc.)': 'diet_alcohol',
    'Yogurt or other foods containing active bacterial cultures (kefir, sauerkraut)': 'diet_live_bacteria',
    'Dairy (milk, cream, ice cream, cheese, cream cheese)': 'diet_dairy',
    'Probiotic': 'diet_probiotic',
    'Fruits (no juice) (Apples, raisins, bananas, oranges, strawberries, blueberries': 'diet_whole_fruits',
    'Vegetables (salad, tomatoes, onions, greens, carrots, peppers, green beans, etc)': 'diet_whole_vegetables',
    'Beans (tofu, soy, soy burgers, lentils, Mexican beans, lima beans etc)': 'diet_beans',
    'Whole grains (wheat, oats, brown rice, rye, quinoa, wheat bread, wheat pasta)': 'diet_whole_grains',
    'Starch (white rice, bread, pizza, potatoes, yams, cereals, pancakes, etc.)': 'diet_starch',
    'Eggs': 'diet_eggs',
    'Processed meat (other red or white meat such as lunch meat, ham, salami, bologna': 'diet_meats_processed',
    'Red meat (beef, hamburger, pork, lamb)': 'diet_meats_red',
    'White meat (chicken, turkey, etc.)': 'diet_meats_white',
    'Shellfish (shrimp, lobster, scallops, etc.)': 'diet_meats_shellfish',
    'Fish (fish nuggets, breaded fish, fish cakes, salmon, tuna, etc.)': 'diet_meats_fish',
    'Sweets (pies, jam, chocolate, cake, cookies, etc.)': 'diet_sweets',
    'Antibiotics': 'status_antibiotics',
    'Chemotherapy': 'status_chemotherapy',
    'Immunosuppressants (e.g. oral corticosteroids)': 'status_immunosuppressants',
    '2) In the past 2 weeks, have you undergone a colonoscopy or other procedure': 'status_recent_colonoscopy',
    '3) In the past 2 weeks, have you used an oral contrast': 'status_oral_contrast',
    '4) In the past 2 weeks, have you had diarrhea?': 'status_diarrhea',
    '5) In the past 2 weeks, have you been hospitalized?': 'status_recent_hospitalization',
    '6) Have you ever had bowel surgery?': 'status_ever_had_bowel_surgery',  # This is with visits because some individuals had surgery during the study.
    'Tea or coffee no sugar and no sugar replacement': 'diet_tea_or_coffee',
    'General wellbeing': 'status_general_wellbeing',
    'sccai': 'status_sccai',
    'Urgency of defecation': 'status_defecation_urgency',
    'Blood in the stool': 'status_blood_in_stool',
    'Abdominal pain': 'status_abdominal_pain',
    'Number of liquid or very soft stools in the past 24 hours:': 'status_number_soft_stools',
    'Abdominal mass': 'status_abdominal_mass',
    'Arthralgia': 'status_arthralgia',
    'hbi': 'status_hbi',
    'CRP (mg/L)': 'status_crp',
    'ESR (mm/hr)': 'status_esr',
    'Weight': 'status_weight',
}


column_replace = {
    'status_antibiotics': {'Yes': True, 'No': False},
    'status_chemotherapy': {'Yes': True, 'No': False},
    'status_immunosuppressants': {'Yes': True, 'No': False},
    'status_recent_colonoscopy': {'Yes': True, 'No': False},
    'status_oral_contrast': {'Yes': True, 'No': False},
    'status_diarrhea': {'Yes': True, 'No': False},
    'status_recent_hospitalization': {'Yes': True, 'No': False},
    'status_ever_had_bowel_surgery': {'Yes': True, 'No': False},
    'status_arthralgia': {'Yes': True, 'No': False},
    'status_weight': {999: np.nan},
    'status_crp': {999: np.nan},
    'status_esr': {999: np.nan},
    'status_number_soft_stools': {999: np.nan}, 
}


_visit = (meta[column_rename.keys()]  # Select columns of interest.
                .rename(columns=column_rename)  # Rename columns.
           )

# Replace malformed values
for col in column_replace:
    _visit[col].replace(column_replace[col], inplace=True)
    
# Fix week numbers
# Week numbers <= zero are sometimes mixed in with other numbers for a single visit number.
def _ifthen(bool, iftrue, iffalse):
    if bool:
        return iftrue
    else:
        return iffalse
    
_visit['week_number'] = _visit['week_number'].map(lambda x: _ifthen(x <= 0, np.nan, x))

# Fill NaNs when other valid values.
_visit = (_visit
                .groupby('visit_id')  
                .apply(lambda d: d.fillna(method='bfill').fillna(method='ffill'))
           )

n_unique_entries = _visit.drop_duplicates().shape[0]
n_unique_visits = _visit.visit_id.unique().shape[0]
assert n_unique_visits == n_unique_entries, (n_unique_visits, n_unique_entries)

print(f"Found {n_unique_visits} unique visits.")

visit = _visit.drop_duplicates().set_index('visit_id')
assert visit.index.is_unique
assert visit.subject_id.isin(subject.index).all()
# Out:
# Found 2302 unique visits.

# %%
# Extract table: 'stool'.

column_rename = {
    'External ID': 'stool_id',
    'site_sub_coll': 'visit_id',
    'fecalcal': 'fecal_calprotectin',
}

_stool = (meta[meta.data_type.isin(  # Exclude host_transcriptomics, methylome, host_genome, serology
                    ['viromics', 'metabolomics',
                     'metagenomics','proteomics',
                     'metagenomics', 'metatranscriptomics',
                     'stool_16S'])]
              [column_rename.keys()]  # Select columns of interest.
               .rename(columns=column_rename)  # Rename columns.
          )

# Remove suffixes _P, _TR.  What do these mean?
_stool.stool_id = _stool.stool_id.str.replace('_TR', '').str.replace('_P', '')

# Fill NaNs when other valid values.
_stool = (_stool
                .groupby('stool_id')  
                .apply(lambda d: d.fillna(method='bfill').fillna(method='ffill'))
           )

n_unique_entries = _stool.drop_duplicates().shape[0]
n_unique_stools = _stool.stool_id.unique().shape[0]
assert n_unique_stools == n_unique_entries, (n_unique_stools, n_unique_entries)

print(f"Found {n_unique_stools} unique stools.")

stool = _stool.drop_duplicates().set_index('stool_id')
assert stool.index.is_unique
assert stool.visit_id.isin(visit.index).all()
# Out:
# Found 1771 unique stools.

# %%
# NOTE: For (just) two samples, the stool ID does not map 1-to-1 with the visit_id.

print(stool.groupby('visit_id').visit_id.count().sort_values().tail())
stool[stool.visit_id.isin(['H4008C19', 'M2039C1'])]
# Out:
# visit_id
# H4006C6     1
# H4006C5     1
# H4007C18    1
# H4008C19    2
# M2039C1     2
# Name: visit_id, dtype: int64
#           visit_id  fecal_calprotectin
# stool_id
# MSM6J2H9   M2039C1           204.08000
# CSM7CZ2F  H4008C19                 NaN
# CSM6J2H9   M2039C1           204.08000
# HSM7CZ2F  H4008C19            72.22479

# %%
# Extract table: 'preparation'.  # Because there are sometimes multiple libraries for the same target library.

column_rename = {
    'Project': 'project_name',
    'External ID': 'external_id',
    'data_type': 'library_type'
}

_preparation = (meta[meta.data_type.isin(  # Exclude host_transcriptomics, methylome, host_genome
                    ['viromics', 'metabolomics',
                     'metagenomics','proteomics',
                     'metagenomics', 'metatranscriptomics',
                     'stool_16S'])]
                   [column_rename.keys()]  # Select columns of interest.
                   .rename(columns=column_rename)  # Rename columns.
          )

# Remove suffixes _P, _TR.  What do these mean?
_preparation['stool_id'] = _preparation.external_id.str.replace('_TR', '').str.replace('_P', '')
# Construct the primary key
_preparation['preparation_id'] = _preparation.stool_id + '_' + _preparation.project_name

# Drop the external_id, this'll be used in a later table
_preparation.drop(columns=['external_id'], inplace=True)

# Fill NaNs when other valid values.
_preparation = (_preparation
                .groupby('preparation_id')  
                .apply(lambda d: d.fillna(method='bfill').fillna(method='ffill'))
           )

n_unique_entries = _preparation.drop_duplicates().shape[0]
n_unique_preparations = _preparation.preparation_id.unique().shape[0]
assert n_unique_preparations == n_unique_entries, (n_unique_preparations, n_unique_entries)

print(f"Found {n_unique_preparations} unique preparations.")

preparation = _preparation.drop_duplicates().set_index('preparation_id')
assert preparation.index.is_unique
assert preparation.stool_id.isin(stool.index).all()
# Out:
# Found 4310 unique preparations.

# %%
# project_name is NOT UNIQUE.
# one counter-example:

preparation[preparation.project_name.isin(preparation[preparation.project_name.duplicated(keep='first')].project_name)]

# These are DIFFERENT people, and the project_name probably isn't _supposed_ to be the same.
# Out:
#                 project_name library_type  stool_id
# preparation_id
# ESM5MEEG_G79115       G79115    stool_16S  ESM5MEEG
# MSM633FF_G79115       G79115    stool_16S  MSM633FF

# %%
# Extract table: 'library'.

column_rename = {
    'Project': 'project_name',
    'External ID': 'external_id',
    'data_type': 'library_type',
    '# Lanes in Aggregation': 'number_of_lanes_aggregated',
    'reads_raw': 'sequenced_reads',
#    'reads_filtered': 'sequenced_reads_filtered',
#    'reads_qc_fail': 'sequenced_reads_qc_fail',
#    'reads_human': 'sequenced_reads_human',
#    'reads_ribosomal': 'sequenced_reads_ribosomal',
#    'reads_viral': 'sequenced_reads_viral',
}

_library = (meta[meta.data_type.isin(  # Exclude host_transcriptomics, methylome, host_genome
                    ['viromics', 'metabolomics',
                     'metagenomics','proteomics',
                     'metagenomics', 'metatranscriptomics',
                     'stool_16S'])]
                   [column_rename.keys()]  # Select columns of interest.
                   .rename(columns=column_rename)  # Rename columns.
          )


# Remove suffixes _P, _TR.  What do these mean?
_library['stool_id'] = _library.external_id.str.replace('_TR', '').str.replace('_P', '')
# Construct the primary key
_library['library_id'] = _library.external_id + '_' + _library.project_name
# Construct the foreign key
_library['preparation_id'] = _library.stool_id + '_' + _library.project_name

_library.drop(columns=['stool_id', 'project_name'], inplace=True)

# Fill NaNs when other valid values.
_library = (_library
                .groupby('library_id')  
                .apply(lambda d: d.fillna(method='bfill').fillna(method='ffill'))
           )

n_unique_entries = _library.drop_duplicates().shape[0]
n_unique_librarys = _library.library_id.unique().shape[0]
assert n_unique_librarys == n_unique_entries, (n_unique_librarys, n_unique_entries)

print(f"Found {n_unique_librarys} unique libraries.")

library = _library.drop_duplicates().set_index('library_id')
assert library.index.is_unique
assert library.preparation_id.isin(preparation.index).all()
# Out:
# Found 4352 unique libraries.

# %%
for name, table in [('subject', subject),
                    ('visit', visit),
                    ('stool', stool),
                    ('preparation', preparation),
                    ('library', library),
                   ]:
    table.to_csv(f'meta/{name}.tsv', sep='\t')
